# %%
import pandas as pd
import numpy as np
import os

# %%
path = r"C:\Users\Kieran\Documents\Career Foundry\Data Immersion\4.0 Python\Instacart Basket Analysis"

# %%
# Import data
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_new_variables.pkl'))

# %%
# first million rows
df = ords_prods_merge[:1000000]

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered _merge  \
# 0                    0.0         196                  1          0   both
# 1                   15.0         196                  1          1   both
# 2                   21.0         196                  1          1   both
# 3                   29.0         196                  1          1   both
# 4                   28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# 0         Soda        77              7     9.0  Mid-range product
# 1         Soda        77              7     9.0  Mid-range product
# 2         Soda        77              7     9.0  Mid-range product
# 3         Soda        77              7     9.0  Mid-range product
# 4         Soda        77              7     9.0  Mid-range product
#
#       busiest day    busiest_days busiest_period_of_day
# 0  Regularly busy  Regularly busy        Average orders
# 1  Regularly busy    Slowest days        Average orders
# 2  Regularly busy    Slowest days           Most orders
# 3      Least busy    Slowest days        Average orders
# 4      Least busy    Slowest days           Most orders

# %%
df.shape
# Out:
# (1000000, 18)

# %% [markdown]
# # Group by

# %% [markdown]
# 1) Split data in to groups based on some criteria
# 2) Apply a function to each group
# 3) Combine results in to df or other data structure or new column

# %%
# this creates an object, but by itself the object will not be visible. Step 1.
df.groupby('product_name')

# %% [markdown]
# # Aggregating with agg()

# %% [markdown]
# Getting a single descriptive statistic (mean) for order_number grouped by department_id. This will allow us to compare average number of orders across departments.

# %%
# split the data, then apply agg()
df.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %% [markdown]
# we dont need the agg() function to calculate mean here

# %%
#note the different syntax
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %% [markdown]
# Multiple aggregations just require adding more arguments

# %%
df.groupby('department_id').agg({'order_number' : ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# # Aggregate data with transform

# %% [markdown]
# 1) Split the data in to groups based on user_id
# 2) Apply transform() to order_number column to get max order for each user
# 3) Results in to new column

# %%
#create new max_order column that contains max order number for each user. 
ords_prods_merge['max order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered _merge  \
# 0                    0.0         196                  1          0   both
# 1                   15.0         196                  1          1   both
# 2                   21.0         196                  1          1   both
# 3                   29.0         196                  1          1   both
# 4                   28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# 0         Soda        77              7     9.0  Mid-range product
# 1         Soda        77              7     9.0  Mid-range product
# 2         Soda        77              7     9.0  Mid-range product
# 3         Soda        77              7     9.0  Mid-range product
# 4         Soda        77              7     9.0  Mid-range product
#
#       busiest day    busiest_days busiest_period_of_day  max order
# 0  Regularly busy  Regularly busy        Average orders         10
# 1  Regularly busy    Slowest days        Average orders         10
# 2  Regularly busy    Slowest days           Most orders         10
# 3      Least busy    Slowest days        Average orders         10
# 4      Least busy    Slowest days           Most orders         10

# %% [markdown]
# Note that within the max_order column, each number will appear the same number of times as its value - because it appears once for each time that user made an order. E.G a user makes 10 orders, therefore their max order number is 10, it appears alongside each order placed - 10 times.

# %% [markdown]
# # Deriving columns with loc()

# %% [markdown]
# As in previous exercise, I will use loc() to create a flag for loyal customer (40+ orders), regular customer (10 >= 40 order), new customer (< 10 orders)

# %%
ords_prods_merge.loc[ords_prods_merge['max order'] <= 10, 'loyalty_flag'] = 'New Customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max order'] > 10) & (ords_prods_merge['max order'] <= 40), 'loyalty_flag'] = 'Regular Customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max order'] < 40, 'loyalty_flag'] = 'Loyal Customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Loyal Customer      15509465
# NaN                 10284093
# New Customer         6243990
# Regular Customer      367311
# Name: loyalty_flag, dtype: int64

# %%
# returning head of only 3 columns
ords_prods_merge[['user_id', 'loyalty_flag', 'max order']].head(50)
# Out:
#     user_id    loyalty_flag  max order
# 0         1    New Customer         10
# 1         1    New Customer         10
# 2         1    New Customer         10
# 3         1    New Customer         10
# 4         1    New Customer         10
# 5         1    New Customer         10
# 6         1    New Customer         10
# 7         1    New Customer         10
# 8         1    New Customer         10
# 9         1    New Customer         10
# 10       15  Loyal Customer         22
# 11       15  Loyal Customer         22
# 12       15  Loyal Customer         22
# 13       15  Loyal Customer         22
# 14       15  Loyal Customer         22
# 15       19    New Customer          9
# 16       19    New Customer          9
# 17       19    New Customer          9
# 18       21  Loyal Customer         33
# 19       31  Loyal Customer         20
# 20       31  Loyal Customer         20
# 21       43  Loyal Customer         11
# 22       43  Loyal Customer         11
# 23       52  Loyal Customer         27
# 24       52  Loyal Customer         27
# 25       52  Loyal Customer         27
# 26       52  Loyal Customer         27
# 27       52  Loyal Customer         27
# 28       52  Loyal Customer         27
# 29       52  Loyal Customer         27
# 30       52  Loyal Customer         27
# 31       52  Loyal Customer         27
# 32       52  Loyal Customer         27
# 33       52  Loyal Customer         27
# 34       52  Loyal Customer         27
# 35       52  Loyal Customer         27
# 36       52  Loyal Customer         27
# 37       67  Loyal Customer         24
# 38       67  Loyal Customer         24
# 39       67  Loyal Customer         24
# 40       67  Loyal Customer         24
# 41       67  Loyal Customer         24
# 42       67  Loyal Customer         24
# 43       67  Loyal Customer         24
# 44       67  Loyal Customer         24
# 45       67  Loyal Customer         24
# 46       67  Loyal Customer         24
# 47       67  Loyal Customer         24
# 48       67  Loyal Customer         24
# 49       67  Loyal Customer         24

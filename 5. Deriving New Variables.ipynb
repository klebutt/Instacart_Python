# %% [markdown]
# ## Contents
# - Price label function
# - Busiest day function
# - Busiest hour function

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r"C:\Users\Kieran\Documents\Career Foundry\Data Immersion\4.0 Python\Instacart Basket Analysis"

# %% [markdown]
# # Import data

# %%
ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# working we subset of data, first million rows
df = ords_prods[:1000000]

# %% [markdown]
# # Defining price label function

# %%
# defining price_label function
def price_label(row):
    if row['prices'] <= 5:
        return 'Low range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid range product'
    elif row['prices'] > 15:
        return 'High range product'
    else: return np.nan

# %%
# applying function to df
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\Kieran\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid range product    756450
# Low range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# # If statements with loc()
# Using loc() applies the conditional logic of if statements without explicitly creating if-else statements.

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\Kieran\anaconda3\lib\site-packages\pandas\core\indexing.py:844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\Kieran\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'
# Out:
# C:\Users\Kieran\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'
# Out:
# C:\Users\Kieran\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # Using loc() on entire dataframe

# %%
ords_prods.loc[ords_prods['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods.loc[(ords_prods['prices'] <= 15) & (ords_prods['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods.loc[ords_prods['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # If Statements with For-Loops

# %% [markdown]
# Busiest day:

# %%
ords_prods['orders_day_of_the_week'].value_counts(dropna = False) # 0 = Sunday
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_the_week, dtype: int64

# %% [markdown]
# New column 'busiest day' created using a for loop

# %%
# empty list
result = []

# %%
# for-loop
for value in ords_prods['orders_day_of_the_week']:
    if value == 0:
        result.append('Busiest day')
    elif value == 4:
        result.append('Least busy')
    else:
        result.append('Regularly busy')

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# creating new column in ords_prods and filling with result list
ords_prods['busiest day'] = result

# %%
ords_prods['busiest day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest day, dtype: int64

# %% [markdown]
# # Exercise

# %% [markdown]
# Q2

# %%
# empty list
busiest_result = []

# %%
#for loop busiest days
for x in ords_prods['orders_day_of_the_week']:
    if x == 0 or x == 1:
        busiest_result.append('Busiest days')
    elif x == 4 or x == 3:
        busiest_result.append('Slowest days')
    else:
        busiest_result.append('Regularly busy')

# %%
# check list
busiest_result
# Out:
# ['Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Regularly busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
# ...

# %%
#add column
ords_prods['busiest_days'] = busiest_result

# %% [markdown]
# Q3

# %%
#check values
ords_prods['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: busiest_days, dtype: int64

# %% [markdown]
# Both the busiest and least busy days have increased in number compared to when I was only counting one day for each. This makes sense as now two days count as 'busy' and two days count as 'slow' or least busy.

# %% [markdown]
# Q4

# %%
#checking column names
ords_prods.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_the_week',
#        'order_hour_of_day', 'days_since_last_order', 'product_id',
#        'add_to_cart_order', 'reordered', '_merge', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'price_range_loc', 'busiest day',
#        'busiest_days'],
#       dtype='object')

# %%
#frequency of order hours
ords_prods['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
# there are 24 hours, so 8 hours in each period. Empty list:
hours = []

# %%
for x in ords_prods['order_hour_of_day']:
    if x in range(9, 16):
        hours.append('Most orders')
    elif x == 7 or x == 8 or x in range(17, 22):
        hours.append('Average orders')
    else:
        hours.append('Fewest orders')

# %%
#add column
ords_prods['busiest_period_of_day'] = hours

# %% [markdown]
# Q5

# %%
#frequency of column
ords_prods['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       18582869
# Average orders     9363426
# Fewest orders      4458564
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# export to pickle

# %%
ords_prods.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_new_variables.pkl'))
